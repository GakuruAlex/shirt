# %%
from PIL import Image, ImageOps

# %%
dir(ImageOps)
# Out:
# ['ExifTags',
#  'Image',
#  'ImagePalette',
#  'Protocol',
#  'Sequence',
#  'SupportsGetMesh',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_border',
#  '_color',
#  '_lut',
#  'annotations',
#  'autocontrast',
#  'cast',
#  'colorize',
#  'contain',
#  'cover',
#  'crop',
#  'deform',
#  'equalize',
#  'exif_transpose',
#  'expand',
#  'fit',
#  'flip',
#  'functools',
#  'grayscale',
#  'invert',
#  'mirror',
#  'operator',
#  'pad',
#  'posterize',
#  're',
#  'scale',
#  'solarize']

# %%
image_g = Image.open("before1.jpg")

# %%
help(image_g.paste)
# Out:
# Help on method paste in module PIL.Image:
#
# paste(im: 'Image | str | float | tuple[float, ...]', box: 'Image | tuple[int, int, int, int] | tuple[int, int] | None' = None, mask: 'Image | None' = None) -> 'None' method of PIL.JpegImagePlugin.JpegImageFile instance
#     Pastes another image into this image. The box argument is either
#     a 2-tuple giving the upper left corner, a 4-tuple defining the
#     left, upper, right, and lower pixel coordinate, or None (same as
#     (0, 0)). See :ref:`coordinate-system`. If a 4-tuple is given, the size
#     of the pasted image must match the size of the region.
#
#     If the modes don't match, the pasted image is converted to the mode of
#     this image (see the :py:meth:`~PIL.Image.Image.convert` method for
#     details).
#
#     Instead of an image, the source can be a integer or tuple
#     containing pixel values.  The method then fills the region
#     with the given color.  When creating RGB images, you can
# ...

# %%
help(image_g.split()[-1])
# Out:
# Help on Image in module PIL.Image object:
#
# class Image(builtins.object)
#  |  Image() -> 'None'
#  |
#  |  This class represents an image object.  To create
#  |  :py:class:`~PIL.Image.Image` objects, use the appropriate factory
#  |  functions.  There's hardly ever any reason to call the Image constructor
#  |  directly.
#  |
#  |  * :py:func:`~PIL.Image.open`
#  |  * :py:func:`~PIL.Image.new`
#  |  * :py:func:`~PIL.Image.frombytes`
#  |
#  |  Methods defined here:
#  |
#  |  __copy__ = copy(self) -> 'Image'
#  |
#  |  __enter__(self)
#  |      # Context manager support
#  |
#  |  __eq__(self, other: 'object') -> 'bool'
#  |      Return self==value.
#  |
#  |  __exit__(self, *args)
#  |
#  |  __getstate__(self) -> 'list[Any]'
#  |      Helper for pickle.
#  |
#  |  __init__(self) -> 'None'
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __repr__(self) -> 'str'
#  |      Return repr(self).
#  |
# ...
